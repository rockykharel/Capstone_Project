# %% [markdown]
# # A Restaurant Recommender System in New York City

# %% [markdown]
# ![merlin_163121409_ec7771d4-c439-410e-bd40-976b2fb5cdca-superJumbo.jpg](attachment:merlin_163121409_ec7771d4-c439-410e-bd40-976b2fb5cdca-superJumbo.jpg)

# %% [markdown]
# In this project, we focus just on New York City so the recommendations will be in the neighborhoods and boroughs of New York City only. We will be rquired with some data sets and integration of those data set is required in order to get the desired outcome. It can be summarize as follows.

# %% [markdown]
# ### 1. New York Data (Boroughs and Neighborhoods) :

# %% [markdown]
# The first dataser we will be using would contain all the required geographical data about New York city. Namely, we will be using 'Borough, Neighborhood, Latitude and Longitude among all the data elements present in the data. We will be using the same data set which was rovided to us in Week 3 of this course.
# https://geo.nyu.edu/catalog/nyu_2451_34572
# We will be using the same link we did to load the data from where it is downloaded and hosted.
# https://cocl.us/new_york_dataset
#
# In total, New York city has 5 boroughs and 306 neighborhoods. To segment them properly and exlore them, we require dataset containing 5 boroughs and the neighborhoods that exist in each of the boroughs as well as latitude and longitude coordinates of each neighborhood. When we extract the latitude and longitude from this dataset, we will use that to perform Clustering using K-Means.
#
# All the relevant data is in the features key, which is basically a list of the neighborhoods. If we look carefully in each elements of the features key, we will get all of the components.
#
# Below is a snapshot of what a single item would look like.

# %% [markdown]
# ![Screenshot%202021-02-27%20030146.png](attachment:Screenshot%202021-02-27%20030146.png)

# %% [markdown]
# ### 2. Four Square City Guide Data (Venues):

# %% [markdown]
# Foursquare City Guide, ordinarily known as Foursquare, is a neighborhood search-and-revelation versatile application which gives list items to its clients. The application gives customized proposals of spots to go almost a user present location dependent on users previous browsing history and registration history.
#
# Before we can figure out how to get information from the Foursquare data set, we need to make an developer account. On May 31st of 2018, Foursquare refreshed their Programming interface, and unlike before, now there are a few impediments on how many calls you can make to the Programming interface (API). So when you make a developer account, the default type is the sandbox account, with 950 normal calls each day and 50 premium calls each day, and you can recover just a single photo and one tip per venue. The account utilized in this project is an individual record which is still free, and with it you get 99,500 regular calls and 500 premium calls.

# %% [markdown]
# That is bascally hundred times greater number of calls than the default sandbox account. You'll additionally gain admittance to more than 105 million venues or points of interest, however you still just get two photographs and two tips for every setting(venue), which is only one more photo and tip contrasted with the sandbox account. The FoursquareAPI credentials you need to make are: your
# Customer ID and your Client Secret. You will need to pass these credentials everytime you make a call to the API.You can go to the onliine Foursquare documentation and clivk on API and find endpoints overview, and there you will locate the various groups and endpoints accessible and whether every endpoint falls under a regular or a premium call.
#
# So utilizing the Foursquare API, we can look for explicit kind of venues or stores around a given area. It is imperative to recall that for this information, we make a regular call to the API, and if you have a free perosnal developer account, you can make up to roughly 99 thousand regular calls each day. We can likewise learn more about a particular venue or store or shop, similar to their full location, their working hours, and their menu on the off chance that they have one, etc. It's likewise essential to remember that for this data, we would make a premium call and witht the personal developer account, you can make on roughly 500 calls each day. Additionally with the
# Foursquare API, we can become familiar with a particular Foursquare user, their complete name, and any tips or photo that they have posted about venues and stores. For this data, a regular call to the Programming interface (API) would be made. Besides, we can exlore a given area by finding what well known spots exist nearby the area, and for this information a regular call to the API would be made. Lastly, with the Foursquare API, we can explore trending venues around a given area. These are venues with the most highest pedestrian activity at the time this regular call to the API is made.
